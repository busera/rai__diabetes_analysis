# %%
import pandas as pd

# %% [markdown]
# # Parameters

# %% [markdown]
# # Test Headline

# %%
print("Hello")
# Out:
# Hello

# %%
# !jupyter --paths
# Out:
# config:
#     /Users/busera/.jupyter
#     /Users/busera/.local/etc/jupyter
#     /Users/busera/Miniconda/miniconda3/envs/langchain_csv/etc/jupyter
#     /usr/local/etc/jupyter
#     /etc/jupyter
# data:
#     /Users/busera/Library/Jupyter
#     /Users/busera/.local/share/jupyter
#     /Users/busera/Miniconda/miniconda3/envs/langchain_csv/share/jupyter
#     /usr/local/share/jupyter
#     /usr/share/jupyter
# runtime:
#     /Users/busera/Library/Jupyter/runtime

# %%
# !jupyter nbconvert test.ipynb --to html --template lab
# !python patch_html_toggle_code.py
# Out:
# [NbConvertApp] Converting notebook test.ipynb to html
# [NbConvertApp] Writing 283108 bytes to test.html
